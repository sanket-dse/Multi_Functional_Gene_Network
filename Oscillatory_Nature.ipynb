# %% [markdown]
# #Verifying Oscillatory nature
#
# Varying constant inputs was given to the system to verify the oscillatory nature.

# %% [markdown]
# ## Defining functions
# 1st value

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import math

# %%
def I(t):
  
  f = 1
  return f

def hposr(x): # THis is for all repressors Positive hill function
  N=1.3
  ka=0.6 #nM 
  hill = x**N/(ka**N+x**N)
  return hill
'''
a= hposr(10) # Just testing hposr function
print(a)
'''
def hnegr(x): # Thus is for repressors Negative hill function
  N=1.3
  ka=0.6 #nM 
  hill = 1/(1+(x**N/ka**N))
  return hill

def hposa(x): #This is for input signal Positive Hill function
  N=1.3
  ka=20.0 #nM 
  hill2 = x**N/(ka**N+x**N)
  #print(hill2)
  return hill2

#b=hposa(10.1) # Just testing hposa function
#print(b)

def func(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,150000,1500000)
x = odeint(func,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#Amplitude of r3 and r1
r3_amp=max(r3)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_1=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_1)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_1=2*t1[index_min]
print(period_1)
# Out:
# 24.014442788114618
# 13.039469513440276
# 38.64508319606955
# 3.155685109231128
# [54817.03654469]

# %% [markdown]
# ## Defining functions
# 2nd value

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import math

# %%
def I1(t):
  
  f = 0.5
  return f


def func1(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I1(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I1(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I1(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I1(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,150000,1500000)
x = odeint(func1,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#Amplitude of r3 and r1
r3_amp=max(r3)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_2=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_2)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_2=2*t1[index_min]
print(period_2)
# Out:
# 18.746466950820576
# 16.273262042029344
# 35.10695317531162
# 3.927756199566167
# [134310.48954033]

# %% [markdown]
# ## Defining functions
# 3rd value

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import math

# %%
def I2(t):
  
  f = 3
  return f


def func2(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I2(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I2(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I2(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I2(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,150000,1500000)
x = odeint(func2,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#modified r3 array
r3_mod=[]
for i in range(600000,1400000):
  r3_mod.append(r3[i])


#Amplitude of r3 and r1
r3_amp=max(r3_mod)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_3=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_3)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_3=2*t1[index_min]
print(period_3)
# Out:
# 34.18478770280356
# 11.240763926274468
# 50.89114822701455
# 1.4800376753700186
# [35791.82386122]

# %% [markdown]
# ## Defining functions
# 4th value

# %%
def I3(t):
  
  f = 5
  return f


def func3(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I3(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I3(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I3(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I3(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,350000,3500000)
x = odeint(func3,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#modified r3 array
r3_mod=[]
for i in range(1500000,2500000):
  r3_mod.append(r3[i])
#Amplitude of r3 and r1
r3_amp=max(r3_mod)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_4=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_4)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_4=2*t1[index_min]
print(period_4)
# Out:
# 30.910472919254985
# 11.221459827915659
# 46.505451223733346
# 0.942008314743595
# [35459.61013132]

# %% [markdown]
# ## Defining functions
# 5th value

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import math

# %%
def I4(t):
  
  f = 6.89
  return f


def func4(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I4(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I4(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I4(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I4(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,350000,3500000)
x = odeint(func4,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#modified r3 array
r3_mod=[]
for i in range(1500000,3000000):
  r3_mod.append(r3[i])

#Amplitude of r3 and r1
r3_amp=max(r3_mod)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_5=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_5)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_5=2*t1[index_min]
print(period_5)
# Out:
# 20.117896789779653
# 10.033239642010177
# 31.792944782081165
# 0.7098815522044786
# [36373.01039229]

# %% [markdown]
# ## Defining functions
# 6th value

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import math

# %%
def I5(t):
  
  f = 3.5
  return f


def func5(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I5(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I5(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I5(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I5(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,350000,3500000)
x = odeint(func5,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#modified r3 array
r3_mod=[]
for i in range(1500000,3000000):
  r3_mod.append(r3[i])

#Amplitude of r3 and r1
r3_amp=max(r3_mod)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_6=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_6)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_6=2*t1[index_min]
print(period_6)
# Out:
# 33.6268174003465
# 11.314920534078412
# 50.1754975096163
# 1.2946635958066859
# [35399.41011412]

# %% [markdown]
# ## Defining functions
# 7th value

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.integrate
import math

# %%
def I6(t):
  
  f = 0.75
  return f


def func6(x,t):
  r1=x[0]
  r2=x[1]
  r3=x[2]
  r4=x[3]
  #parameter initialization
  ktl=6E-4
  delm=2.5E-3
  delr=4E-4
  beta=0.4 #nM/s
  Ptc=0.4 #nM/s
  alpha=ktl*beta/delm #for a1,b1,c1,d1
  gamma=ktl*Ptc/delm # For a2,b2,c2,d2

  # defining equations
  dr1dt= alpha*hposa(I6(t))*hnegr(r2) + gamma*hnegr(r3) - delr*r1
  dr2dt= alpha*hposa(I6(t))*hnegr(r4) + gamma*hnegr(r3)*hnegr(r4) - delr*r2
  dr3dt= alpha*hposa(I6(t))*hnegr(r4) + gamma*hnegr(r1) - delr*r3
  dr4dt= alpha*hposa(I6(t))*hnegr(r2) + gamma*hnegr(r1)*hnegr(r2) - delr*r4

  return [dr1dt,dr2dt,dr3dt,dr4dt]

# %% [markdown]
# ## Solving and Plotting

# %%
from scipy.integrate import odeint
import numpy as np

x0=[50.0,50.0,0.0,0.0]
t1=np.linspace(0,350000,3500000)
x = odeint(func6,x0,t1)

r1=x[:,0]
r2=x[:,1]
r3=x[:,2]
r4=x[:,3]

# %%
plt.plot(t1,r1)
plt.plot(t1,r2)
plt.plot(t1,r3)
plt.plot(t1,r4)
plt.xlabel('Time(s)')
plt.ylabel('Concentration(nM)')
plt.legend(['R1','R2','R3','R4'])
plt.show()

# %% [markdown]
# ## Finding l2 norms and time periods

# %%
#modified r3 array
r3_mod=[]
for i in range(1500000,3000000):
  r3_mod.append(r3[i])

#Amplitude of r3 and r1
r3_amp=max(r3_mod)
print(r3_amp)

#Amplitude of r4 and r2
r4_amp=max(r4)
print(r4_amp)

l2_norm_7=math.sqrt(2*r3_amp**2+2*r4_amp**2)
print(l2_norm_7)

# find minimum point of r1
r1_min=min(r1)
print(r1_min)

#find timepoint for minima
index_min=np.where(r1==r1_min)
period_7=2*t1[index_min]
print(period_7)
# Out:
# 20.518980109503932
# 14.05998906599888
# 35.177033339104256
# 3.553506391980609
# [71630.22046578]

# %% [markdown]
# ## Figure 6 a&b Graphs

# %%
x=[I(0),I1(0),I2(0),I3(0),I4(0),I5(9),I6(0)] 
#x_mod=[]# Input concentrations
print(x)
# Out:
# [1, 0.5, 3, 5, 6.89, 3.5, 0.75]

# %%
from scipy.interpolate import make_interp_spline

x=[I1(0),I6(0),I(0),I2(0),I5(0),I3(9),I4(0)] 


y_l2norm=[l2_norm_2,l2_norm_7,l2_norm_1,l2_norm_3,l2_norm_6,l2_norm_4,l2_norm_5] #l2 norms of R1-R4 amplitudes
y_period=[period_2,period_7,period_1,period_3,period_6,period_4,period_5] #Period of oscillations

X_Y_Spline = make_interp_spline(x, y_l2norm)
X_Y_Spline1 = make_interp_spline(x,y_period)

 
# Returns evenly spaced numbers
# over a specified interval.
X_ = np.linspace(min(x), max(x), 500)
Y_ = X_Y_Spline(X_)
Y_1 = X_Y_Spline1(X_)



plot1=plt.figure(1)
plt.plot(X_, Y_)
plt.title("L2 norm v/s Input Concentration")
plt.xlabel("Input concentration(nM)")
plt.ylabel("L2 norm")
plt.title('Fig 6 : Effect of input concentration on oscillatory characteristics')
plt.grid()



plot2=plt.figure(2)
plt.plot(X_, Y_1)
plt.title("Period v/s Input Concentration")
plt.xlabel("Input concentration(nM)")
plt.ylabel("Period(s)")

plt.grid()

plt.show()
